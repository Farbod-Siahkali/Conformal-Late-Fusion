# %%
"""
CIFAR-100 ablation study (K=4) — RESNET18 BASELINE + NORMALIZATION

ONLY CHANGE vs your pasted script:
  - Backbone: ResNet-18 (instead of EfficientNet-B0)
  - Keep Resize FIRST on the full image, THEN split into patches (resize->patch)

Notes:
  - If you set full_image_size=224, batch_size=8192 will likely OOM. Lower batch_size.
"""

from __future__ import annotations

import os
import warnings
from dataclasses import dataclass
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
from scipy.stats import chi2

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.transforms import Resize

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# =========================
# Plot style (NO seaborn)
# =========================
import matplotlib as mpl
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

try:
    import scienceplots  # noqa: F401
    plt.style.use(["science", "no-latex"])
except Exception as e:
    print("[WARN] scienceplots not found or style failed; using default matplotlib style.", e)

mpl.rcParams["pdf.fonttype"] = 42
mpl.rcParams["ps.fonttype"] = 42
mpl.rcParams.update(
    {
        "font.size": 8,
        "axes.titlesize": 9,
        "axes.labelsize": 8,
        "xtick.labelsize": 7,
        "ytick.labelsize": 7,
        "legend.fontsize": 6,
        "lines.linewidth": 1.0,
        "axes.linewidth": 0.5,
    }
)

# =============================================================================
# Config (MATCH your CIFAR-100 experiment params)
# =============================================================================

@dataclass
class AblationConfig100:
    alpha: float = 0.1
    num_classes: int = 100
    num_simulations: int = 10

    # training (match CIFAR-100 experiment)
    epochs_per_view: int = 150
    lr: float = 1e-3
    batch_size: int = 1024
    max_iter_lr: int = 2000
    train_seed_base: int = 41

    # dataloader
    num_workers: int = 4

    # data split fractions (match CIFAR-100 experiment)
    train_frac: float = 0.5
    cal_frac_of_temp: float = 0.3
    fuse_train_frac_of_rest: float = 0.7

    # Ablation target
    K_target: int = 4

    # Ablation sweep
    nt_fracs: Tuple[float, ...] = tuple(np.round(np.linspace(0.1, 1.0, 10), 2))

    # Fusion MLP (2-layer) hyperparams
    fusion_epochs: int = 50
    fusion_hidden1: int = 512
    fusion_hidden2: int = 512
    fusion_weight_decay: float = 1e-4
    fusion_batch_size: int = 4096

    # ResNet / preprocessing
    pretrained_backbone: bool = True
    normalization: str = "imagenet"  # "imagenet" or "cifar100"

    # Resize FULL image BEFORE splitting into patches
    # 224 makes patches 112x112 for K=4.
    full_image_size: int = 128

    # Output
    out_dir: str = "cifar100_ablation_outputs2"


# =============================================================================
# Torch / Data
# =============================================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# keep CIFAR as raw tensors/numpy; normalize in PatchesDataset
transform = transforms.Compose([transforms.ToTensor()])

train_dataset = datasets.CIFAR100(root="./data", train=True, download=True, transform=transform)
test_dataset  = datasets.CIFAR100(root="./data", train=False, download=True, transform=transform)

X_train_full = train_dataset.data.astype(np.float32) / 255.0  # (N,32,32,3)
Y_train_full = np.array(train_dataset.targets, dtype=int)
X_test_full  = test_dataset.data.astype(np.float32) / 255.0
Y_test_full  = np.array(test_dataset.targets, dtype=int)

# =============================================================================
# Multi-view (patch) utilities
# =============================================================================

def split_image_into_k_patches(image: torch.Tensor, k: int) -> List[torch.Tensor]:
    """
    image: (C,H,W)
    For k=4, split into a 2x2 grid using the CURRENT H,W.
    """
    C, H, W = image.shape
    if k == 4:
        h2 = H // 2
        w2 = W // 2
        patches = []
        for i in range(2):
            for j in range(2):
                patch = image[:, i * h2 : (i + 1) * h2, j * w2 : (j + 1) * w2]
                patches.append(patch)
        return patches
    else:
        # split along width into k vertical strips
        base_width = W // k
        remainder = W % k
        patches, start = [], 0
        for idx in range(k):
            width = base_width + (1 if idx < remainder else 0)
            patch = image[:, :, start : start + width]
            patches.append(patch)
            start += width
        return patches


class PatchesDataset(torch.utils.data.Dataset):
    def __init__(
        self,
        images: np.ndarray,
        labels: np.ndarray,
        k: int,
        view: int,
        normalization: str = "imagenet",
        full_image_size: int = 224,
    ):
        self.images = images
        self.labels = labels
        self.k = k
        self.view = view

        # resize FULL image first (before patching)
        self.resize = Resize((full_image_size, full_image_size))

        # Normalization choices
        if normalization.lower() == "cifar100":
            mean = (0.5071, 0.4867, 0.4408)
            std  = (0.2675, 0.2565, 0.2761)
        else:
            # ImageNet mean/std (recommended with ImageNet-pretrained backbones)
            mean = (0.485, 0.456, 0.406)
            std  = (0.229, 0.224, 0.225)

        self.normalize = transforms.Normalize(mean=mean, std=std)

    def __len__(self) -> int:
        return len(self.labels)

    def __getitem__(self, idx: int):
        # images are float32 in [0,1], shape (32,32,3)
        img = torch.from_numpy(self.images[idx]).permute(2, 0, 1).contiguous()  # (3,32,32)

        # resize first, then patch
        img = self.resize(img)  # (3,full_image_size,full_image_size)
        patches = split_image_into_k_patches(img, self.k)
        patch = patches[self.view]         # for K=4, (3, full_image_size/2, full_image_size/2)
        patch = self.normalize(patch)      # normalize AFTER resize (and after patching)

        y = int(self.labels[idx])
        return patch, y


# =============================================================================
# ResNet-18 per view (baseline)
# =============================================================================

from torchvision.models import resnet18, ResNet18_Weights


class PredictorCNN(nn.Module):
    def __init__(self, num_classes: int = 100, pretrained: bool = True):
        super().__init__()
        weights = ResNet18_Weights.IMAGENET1K_V1 if pretrained else None
        self.model = resnet18(weights=weights)
        in_features = self.model.fc.in_features
        self.model.fc = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)


def train_model(model: nn.Module, train_loader, num_epochs: int, lr: float):
    crit = nn.CrossEntropyLoss()
    opt = optim.Adam(model.parameters(), lr=lr)
    model.to(device)

    for ep in range(num_epochs):
        model.train()
        for xb, yb in train_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True) if torch.is_tensor(yb) else torch.tensor(
                yb, dtype=torch.long, device=device
            )

            opt.zero_grad(set_to_none=True)
            loss = crit(model(xb), yb)
            loss.backward()
            opt.step()

        if (ep + 1) % 25 == 0:
            print(f"  epoch {ep+1}/{num_epochs}")
    return model


# =============================================================================
# Conformal utilities
# =============================================================================

def compute_nonconformity_scores(model: nn.Module, loader) -> Tuple[np.ndarray, np.ndarray]:
    model.eval()
    scores, labels = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, non_blocking=True)
            yb_t = yb.to(device, non_blocking=True) if torch.is_tensor(yb) else torch.tensor(
                yb, dtype=torch.long, device=device
            )

            logits = model(xb)
            probs = F.softmax(logits, dim=1)
            idx = torch.arange(probs.size(0), device=probs.device)
            true_p = probs[idx, yb_t]
            s = (1.0 - true_p).detach().cpu().numpy()
            scores.extend(s)
            labels.extend(yb.cpu().numpy() if torch.is_tensor(yb) else np.asarray(yb))
    return np.asarray(scores, float), np.asarray(labels, int)


def classwise_scores(scores: np.ndarray, labels: np.ndarray, L: int) -> Dict[int, np.ndarray]:
    out = {c: [] for c in range(L)}
    for s, y in zip(scores, labels):
        out[int(y)].append(float(s))
    return {c: np.asarray(v, float) for c, v in out.items()}


def per_view_pvalues_and_probs(
    model: nn.Module, class_scores: Dict[int, np.ndarray], loader, L: int
) -> Tuple[np.ndarray, np.ndarray]:
    model.eval()
    probs_all = []
    with torch.no_grad():
        for xb, _ in loader:
            xb = xb.to(device, non_blocking=True)
            logits = model(xb)
            probs = F.softmax(logits, dim=1).detach().cpu().numpy()
            probs_all.append(probs)
    probs_all = np.vstack(probs_all)  # (n, L)

    n = probs_all.shape[0]
    pvals = np.zeros((n, L), dtype=float)
    for y in range(L):
        cal = class_scores.get(y, np.array([], dtype=float))
        if cal.size == 0:
            pvals[:, y] = 1.0
        else:
            s_test = 1.0 - probs_all[:, y]
            counts = np.sum(cal[:, None] >= s_test[None, :], axis=0)
            pvals[:, y] = (1.0 + counts) / (len(cal) + 1.0)
    return pvals, probs_all


# =============================================================================
# Fusion + baselines
# =============================================================================

def build_fusion_features(pvals_list: List[np.ndarray], probs_list: List[np.ndarray]) -> np.ndarray:
    blocks = [np.hstack([pvals_list[k], probs_list[k]]) for k in range(len(pvals_list))]
    return np.hstack(blocks)


def fisher_fusion(P_all: np.ndarray) -> np.ndarray:
    eps = 1e-12
    p = np.clip(P_all, eps, 1.0)
    T = -2 * np.sum(np.log(p), axis=0)
    df = 2 * P_all.shape[0]
    return 1 - chi2.cdf(T, df=df)


def adjusted_fisher_fusion(P_train: np.ndarray, y_train: np.ndarray, P_test: np.ndarray, L: int) -> np.ndarray:
    K, _, _ = P_train.shape
    n_test = P_test.shape[1]
    eps = 1e-12
    out = np.zeros((n_test, L), dtype=float)
    for y in range(L):
        idx = np.where(y_train == y)[0]
        if idx.size < 5:
            out[:, y] = fisher_fusion(P_test)[:, y]
            continue
        P_cls = np.clip(P_train[:, idx, y], eps, 1.0)
        W = -2 * np.log(P_cls)
        Wc = W - W.mean(axis=1, keepdims=True)
        Sigma = (Wc @ Wc.T) / max(W.shape[1] - 1, 1)
        var_T = np.sum(Sigma)
        if not np.isfinite(var_T) or var_T <= 0:
            var_T = 4 * K
        f_y = (8.0 * K * K) / var_T
        c_y = var_T / (4 * K)

        P_t = np.clip(P_test[:, :, y], eps, 1.0)
        T_t = -2 * np.sum(np.log(P_t), axis=0)
        out[:, y] = 1 - chi2.cdf(T_t / c_y, df=f_y)
    return out


def fused_class_cal_scores(y_cal: np.ndarray, fused_probs_cal: np.ndarray, L: int) -> Dict[int, np.ndarray]:
    s = 1.0 - fused_probs_cal[np.arange(len(y_cal)), y_cal]
    out = {c: [] for c in range(L)}
    for sc, yy in zip(s, y_cal):
        out[int(yy)].append(float(sc))
    return {c: np.asarray(v, float) for c, v in out.items()}


def fused_p_values_from_cal(fused_probs: np.ndarray, cal_class_scores: Dict[int, np.ndarray]) -> np.ndarray:
    n, L = fused_probs.shape
    out = np.zeros((n, L), dtype=float)
    for y in range(L):
        cal = cal_class_scores.get(y, np.array([], dtype=float))
        if cal.size == 0:
            out[:, y] = 1.0
        else:
            s_test = 1.0 - fused_probs[:, y]
            counts = np.sum(cal[:, None] >= s_test[None, :], axis=0)
            out[:, y] = (1.0 + counts) / (len(cal) + 1.0)
    return out


def evaluate_sets(P: np.ndarray, y_true: np.ndarray, alpha: float) -> Tuple[float, float]:
    C = (P > alpha)
    cov = float(np.mean(C[np.arange(len(y_true)), y_true]))
    size = float(np.mean(C.sum(axis=1)))
    return cov, size


# =============================================================================
# Fusion MLP (2 hidden layers) + training/predict
# =============================================================================

class FusionMLP(nn.Module):
    def __init__(self, d_in: int, d_h1: int, d_h2: int, d_out: int):
        super().__init__()
        self.fc1 = nn.Linear(d_in, d_h1)
        self.fc2 = nn.Linear(d_h1, d_h2)
        self.fc3 = nn.Linear(d_h2, d_out)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


def set_all_seeds(seed: int):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False


def train_fusion_mlp(
    X: np.ndarray,
    y: np.ndarray,
    d_in: int,
    L: int,
    seed: int,
    epochs: int,
    lr: float,
    weight_decay: float,
    batch_size: int,
    hidden1: int,
    hidden2: int,
) -> FusionMLP:
    set_all_seeds(seed)
    model = FusionMLP(d_in, hidden1, hidden2, L).to(device)
    opt = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    crit = nn.CrossEntropyLoss()

    X_t = torch.tensor(X, dtype=torch.float32)
    y_t = torch.tensor(y, dtype=torch.long)
    ds = torch.utils.data.TensorDataset(X_t, y_t)
    dl = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True)

    model.train()
    for _ in range(epochs):
        for xb, yb in dl:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            opt.zero_grad(set_to_none=True)
            loss = crit(model(xb), yb)
            loss.backward()
            opt.step()
    return model


@torch.no_grad()
def fusion_mlp_predict_proba(model: FusionMLP, X: np.ndarray, batch_size: int = 8192) -> np.ndarray:
    model.eval()
    X_t = torch.tensor(X, dtype=torch.float32)
    dl = torch.utils.data.DataLoader(X_t, batch_size=batch_size, shuffle=False)
    probs = []
    for xb in dl:
        xb = xb.to(device, non_blocking=True)
        logits = model(xb)
        probs.append(F.softmax(logits, dim=1).detach().cpu().numpy())
    return np.vstack(probs)


# =============================================================================
# Subsampling helper (stratified)
# =============================================================================

def stratified_subsample_indices(y: np.ndarray, n_sub: int, seed: int) -> np.ndarray:
    n = len(y)
    n_sub = int(max(1, min(n_sub, n)))
    idx_all = np.arange(n, dtype=int)
    if n_sub >= n:
        return idx_all
    idx_sub, _ = train_test_split(idx_all, train_size=n_sub, stratify=y, random_state=seed)
    return np.asarray(idx_sub, dtype=int)


# =============================================================================
# Main ablation (CIFAR-100, K=4): CLF(LR) vs CLF(MLP) vs AdjF
# =============================================================================

def run_ablation(cfg: AblationConfig100) -> pd.DataFrame:
    os.makedirs(cfg.out_dir, exist_ok=True)
    rows = []

    pin = bool(torch.cuda.is_available())

    for sim in range(cfg.num_simulations):
        print(f"\n=== Simulation {sim+1}/{cfg.num_simulations} ===")
        seed = cfg.train_seed_base + sim

        # EXACT splits as your CIFAR-100 experiment
        X_trP, X_tmp, y_trP, y_tmp = train_test_split(
            X_train_full,
            Y_train_full,
            test_size=1 - cfg.train_frac,
            stratify=Y_train_full,
            random_state=seed,
        )
        X_cal, X_rest, y_cal, y_rest = train_test_split(
            X_tmp,
            y_tmp,
            test_size=1 - cfg.cal_frac_of_temp,
            stratify=y_tmp,
            random_state=seed,
        )
        X_fuse_tr_full, X_fuse_cal, y_fuse_tr_full, y_fuse_cal = train_test_split(
            X_rest,
            y_rest,
            test_size=1 - cfg.fuse_train_frac_of_rest,
            stratify=y_rest,
            random_state=seed,
        )

        X_te, y_te = X_test_full, Y_test_full
        K = cfg.K_target
        num_views = 4  # K=4 special-case

        print(f"\n  -> K = {K} (ablation target)")

        # loaders per view
        loaders = {}
        for v in range(num_views):
            tr_loader = torch.utils.data.DataLoader(
                PatchesDataset(
                    X_trP, y_trP, K, v,
                    normalization=cfg.normalization,
                    full_image_size=cfg.full_image_size,
                ),
                batch_size=cfg.batch_size,
                shuffle=True,
                num_workers=cfg.num_workers,
                pin_memory=pin,
                persistent_workers=(cfg.num_workers > 0),
            )
            cal_loader = torch.utils.data.DataLoader(
                PatchesDataset(
                    X_cal, y_cal, K, v,
                    normalization=cfg.normalization,
                    full_image_size=cfg.full_image_size,
                ),
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=pin,
                persistent_workers=(cfg.num_workers > 0),
            )
            ftr_loader = torch.utils.data.DataLoader(
                PatchesDataset(
                    X_fuse_tr_full, y_fuse_tr_full, K, v,
                    normalization=cfg.normalization,
                    full_image_size=cfg.full_image_size,
                ),
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=pin,
                persistent_workers=(cfg.num_workers > 0),
            )
            fcal_loader = torch.utils.data.DataLoader(
                PatchesDataset(
                    X_fuse_cal, y_fuse_cal, K, v,
                    normalization=cfg.normalization,
                    full_image_size=cfg.full_image_size,
                ),
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=pin,
                persistent_workers=(cfg.num_workers > 0),
            )
            te_loader = torch.utils.data.DataLoader(
                PatchesDataset(
                    X_te, y_te, K, v,
                    normalization=cfg.normalization,
                    full_image_size=cfg.full_image_size,
                ),
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=pin,
                persistent_workers=(cfg.num_workers > 0),
            )
            loaders[v] = dict(train=tr_loader, cal=cal_loader, ftr=ftr_loader, fcal=fcal_loader, te=te_loader)

        # Train per-view predictors
        models: List[PredictorCNN] = []
        cal_classwise: List[Dict[int, np.ndarray]] = []
        for v in range(num_views):
            print(f"    [View {v+1}/{num_views}] training ResNet-18...")
            m = PredictorCNN(num_classes=cfg.num_classes, pretrained=cfg.pretrained_backbone)
            m = train_model(m, loaders[v]["train"], num_epochs=cfg.epochs_per_view, lr=cfg.lr)
            models.append(m)

            sc, lab = compute_nonconformity_scores(m, loaders[v]["cal"])
            cal_classwise.append(classwise_scores(sc, lab, cfg.num_classes))

        # Per-view p/probs for fusion train full, cal2, and test
        pv_tr_full, pr_tr_full = [], []
        pv_cal2, pr_cal2 = [], []
        pv_te, pr_te = [], []
        for v in range(num_views):
            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["ftr"], cfg.num_classes)
            pv_tr_full.append(p)
            pr_tr_full.append(pr)

            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["fcal"], cfg.num_classes)
            pv_cal2.append(p)
            pr_cal2.append(pr)

            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["te"], cfg.num_classes)
            pv_te.append(p)
            pr_te.append(pr)

        P_test = np.stack(pv_te, axis=0)  # (K, n_test, L)

        X_cal2_feat = build_fusion_features(pv_cal2, pr_cal2)
        X_test_feat = build_fusion_features(pv_te, pr_te)

        n_t_full = len(y_fuse_tr_full)

        # free per-view models from GPU before fusion sweeps
        for m in models:
            m.to("cpu")
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

        for frac in cfg.nt_fracs:
            n_sub = int(round(frac * n_t_full))
            idx_sub = stratified_subsample_indices(
                y_fuse_tr_full, n_sub, seed=seed + int(frac * 1000)
            )

            y_tr_sub = y_fuse_tr_full[idx_sub]
            pv_tr_sub = [pv[idx_sub] for pv in pv_tr_full]
            pr_tr_sub = [pr[idx_sub] for pr in pr_tr_full]

            X_ftr_sub = build_fusion_features(pv_tr_sub, pr_tr_sub)
            d_in = X_ftr_sub.shape[1]

            # (A) CLF (LR)
            fusion_lr = LogisticRegression(
                max_iter=cfg.max_iter_lr,
                multi_class="multinomial",
                solver="lbfgs",
                random_state=seed,
            )
            fusion_lr.fit(X_ftr_sub, y_tr_sub)

            fused_probs_cal2_lr = fusion_lr.predict_proba(X_cal2_feat)
            fused_cal_scores_lr = fused_class_cal_scores(y_fuse_cal, fused_probs_cal2_lr, cfg.num_classes)

            fused_probs_test_lr = fusion_lr.predict_proba(X_test_feat)
            P_cf_lr = fused_p_values_from_cal(fused_probs_test_lr, fused_cal_scores_lr)

            cov_lr, size_lr = evaluate_sets(P_cf_lr, y_te, cfg.alpha)

            # (B) CLF (MLP)
            fusion_mlp = train_fusion_mlp(
                X=X_ftr_sub,
                y=y_tr_sub,
                d_in=d_in,
                L=cfg.num_classes,
                seed=seed + 12345 + int(frac * 1000),
                epochs=cfg.fusion_epochs,
                lr=cfg.lr,
                weight_decay=cfg.fusion_weight_decay,
                batch_size=cfg.fusion_batch_size,
                hidden1=cfg.fusion_hidden1,
                hidden2=cfg.fusion_hidden2,
            )

            fused_probs_cal2_mlp = fusion_mlp_predict_proba(
                fusion_mlp, X_cal2_feat, batch_size=cfg.fusion_batch_size
            )
            fused_cal_scores_mlp = fused_class_cal_scores(y_fuse_cal, fused_probs_cal2_mlp, cfg.num_classes)

            fused_probs_test_mlp = fusion_mlp_predict_proba(
                fusion_mlp, X_test_feat, batch_size=cfg.fusion_batch_size
            )
            P_cf_mlp = fused_p_values_from_cal(fused_probs_test_mlp, fused_cal_scores_mlp)

            cov_mlp, size_mlp = evaluate_sets(P_cf_mlp, y_te, cfg.alpha)

            # (C) Adjusted Fisher
            P_train_sub = np.stack(pv_tr_sub, axis=0)
            P_adjF = adjusted_fisher_fusion(P_train_sub, y_tr_sub, P_test, cfg.num_classes)
            cov_adjF, size_adjF = evaluate_sets(P_adjF, y_te, cfg.alpha)

            rows.append(
                dict(
                    sim=sim,
                    seed=seed,
                    K=K,
                    alpha=cfg.alpha,
                    nt_frac=float(frac),
                    nt_sub=int(len(idx_sub)),
                    nt_full=int(n_t_full),
                    cov_clf_lr=float(cov_lr),
                    size_clf_lr=float(size_lr),
                    cov_clf_mlp=float(cov_mlp),
                    size_clf_mlp=float(size_mlp),
                    cov_adjF=float(cov_adjF),
                    size_adjF=float(size_adjF),
                )
            )

            print(
                f"    nt_frac={frac:.2f} (n={len(idx_sub):5d}) | "
                f"CLF-LR: cov={cov_lr:.3f}, size={size_lr:.3f} | "
                f"CLF-MLP: cov={cov_mlp:.3f}, size={size_mlp:.3f} | "
                f"AdjF: cov={cov_adjF:.3f}, size={size_adjF:.3f}"
            )

    df = pd.DataFrame(rows)
    out_csv = os.path.join(cfg.out_dir, "cifar100_ablation_ntfrac_results.csv")
    df.to_csv(out_csv, index=False)
    print(f"\nSaved raw results to: {out_csv}")
    return df


def plot_ablation(df: pd.DataFrame, cfg: AblationConfig100):
    g = df.groupby("nt_frac").agg(
        cov_lr_mean=("cov_clf_lr", "mean"),
        cov_lr_std=("cov_clf_lr", "std"),
        size_lr_mean=("size_clf_lr", "mean"),
        size_lr_std=("size_clf_lr", "std"),
        cov_mlp_mean=("cov_clf_mlp", "mean"),
        cov_mlp_std=("cov_clf_mlp", "std"),
        size_mlp_mean=("size_clf_mlp", "mean"),
        size_mlp_std=("size_clf_mlp", "std"),
        cov_adjF_mean=("cov_adjF", "mean"),
        cov_adjF_std=("cov_adjF", "std"),
        size_adjF_mean=("size_adjF", "mean"),
        size_adjF_std=("size_adjF", "std"),
        nt_sub_mean=("nt_sub", "mean"),
    ).reset_index().sort_values("nt_frac")

    out_agg = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_agg_K{cfg.K_target}.csv")
    g.to_csv(out_agg, index=False)
    print(f"Saved aggregated table to: {out_agg}")

    x = g["nt_frac"].to_numpy()
    xlab = r"Fusion-train fraction $n_{\mathrm{fuse}} / n_t$"

    fig, axes = plt.subplots(2, 1, figsize=(3.35, 3.10), dpi=300, sharex=True)

    # Coverage
    ax = axes[0]
    ax.plot(x, 100.0 * g["cov_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        100.0 * (g["cov_lr_mean"] - g["cov_lr_std"].fillna(0)),
        100.0 * (g["cov_lr_mean"] + g["cov_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_mlp_mean"], label="CLF (MLP)", linestyle="-.")
    ax.fill_between(
        x,
        100.0 * (g["cov_mlp_mean"] - g["cov_mlp_std"].fillna(0)),
        100.0 * (g["cov_mlp_mean"] + g["cov_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        100.0 * (g["cov_adjF_mean"] - g["cov_adjF_std"].fillna(0)),
        100.0 * (g["cov_adjF_mean"] + g["cov_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.axhline(100.0 * (1.0 - cfg.alpha), linestyle=":", linewidth=0.8, label=r"Target $1-\alpha$")
    ax.set_ylabel("Coverage (%)")
    ax.set_title(r"CIFAR-100 (K=4): Coverage vs $n_{\mathrm{fuse}}/n_t$")
    ax.set_ylim(100.0 * (1.0 - cfg.alpha) - 5.0, 100.0 * (1.0 - cfg.alpha) + 5.0)
    ax.legend(frameon=False, ncol=2)

    # Set size
    ax = axes[1]
    ax.plot(x, g["size_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        (g["size_lr_mean"] - g["size_lr_std"].fillna(0)),
        (g["size_lr_mean"] + g["size_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_mlp_mean"], label="CLF (MLP)", linestyle="-.")
    ax.fill_between(
        x,
        (g["size_mlp_mean"] - g["size_mlp_std"].fillna(0)),
        (g["size_mlp_mean"] + g["size_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        (g["size_adjF_mean"] - g["size_adjF_std"].fillna(0)),
        (g["size_adjF_mean"] + g["size_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.set_xlabel(xlab)
    ax.set_ylabel("Avg. set size")
    ax.set_title(r"CIFAR-100 (K=4): Set size vs $n_{\mathrm{fuse}}/n_t$")
    ax.legend(frameon=False, ncol=2)

    ax.set_xticks(x)
    for tick in ax.get_xticklabels():
        tick.set_rotation(45)
        tick.set_ha("right")

    fig.tight_layout()

    out_pdf = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}.pdf")
    out_png = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}.png")
    fig.savefig(out_pdf, bbox_inches="tight")
    fig.savefig(out_png, bbox_inches="tight")
    print(f"Saved figure to:\n  {out_pdf}\n  {out_png}")

    plt.show()


cfg = AblationConfig100()
df = run_ablation(cfg)
plot_ablation(df, cfg)


mpl.rcParams["pdf.fonttype"] = 42
mpl.rcParams["ps.fonttype"] = 42
mpl.rcParams.update(
    {
        "font.size": 8,
        "axes.titlesize": 9,
        "axes.labelsize": 8,
        "xtick.labelsize": 7,
        "ytick.labelsize": 7,
        "legend.fontsize": 5,
        "lines.linewidth": 1.0,
        "axes.linewidth": 0.5,
    }
)

def plot_ablation2(df: pd.DataFrame, cfg: AblationConfig100):
    g = df.groupby("nt_frac").agg(
        cov_lr_mean=("cov_clf_lr", "mean"),
        cov_lr_std=("cov_clf_lr", "std"),
        size_lr_mean=("size_clf_lr", "mean"),
        size_lr_std=("size_clf_lr", "std"),
        cov_mlp_mean=("cov_clf_mlp", "mean"),
        cov_mlp_std=("cov_clf_mlp", "std"),
        size_mlp_mean=("size_clf_mlp", "mean"),
        size_mlp_std=("size_clf_mlp", "std"),
        cov_adjF_mean=("cov_adjF", "mean"),
        cov_adjF_std=("cov_adjF", "std"),
        size_adjF_mean=("size_adjF", "mean"),
        size_adjF_std=("size_adjF", "std"),
        nt_sub_mean=("nt_sub", "mean"),
    ).reset_index().sort_values("nt_frac")

    out_agg = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_agg_K{cfg.K_target}.csv")
    g.to_csv(out_agg, index=False)
    print(f"Saved aggregated table to: {out_agg}")

    x = g["nt_frac"].to_numpy()
    xlab = r"Fusion-train fraction $n_{\mathrm{fuse}} / n_t$"

    # --- One-column, side-by-side panels ---
    # Typical 2-col paper column width: ~3.35 inches. Keep height modest.
    fig, axes = plt.subplots(
        1, 2,
        figsize=(3.54, 2),  # width=one column, height tuned for readability
        dpi=300,
        sharex=True
    )

    # =========================
    # Left: Coverage
    # =========================
    ax = axes[0]
    ax.plot(x, 100.0 * g["cov_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        100.0 * (g["cov_lr_mean"] - g["cov_lr_std"].fillna(0)),
        100.0 * (g["cov_lr_mean"] + g["cov_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_mlp_mean"], label="CLF (MLP)", linestyle="-.")
    ax.fill_between(
        x,
        100.0 * (g["cov_mlp_mean"] - g["cov_mlp_std"].fillna(0)),
        100.0 * (g["cov_mlp_mean"] + g["cov_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        100.0 * (g["cov_adjF_mean"] - g["cov_adjF_std"].fillna(0)),
        100.0 * (g["cov_adjF_mean"] + g["cov_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.axhline(100.0 * (1.0 - cfg.alpha), linestyle=":", linewidth=0.8)
    ax.set_title("Coverage")
    ax.set_ylabel("Coverage (%)")
    ax.set_ylim(100.0 * (1.0 - cfg.alpha) - 5.0, 100.0 * (1.0 - cfg.alpha) + 5.0)

    # =========================
    # Right: Set size
    # =========================
    ax = axes[1]
    ax.plot(x, g["size_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        (g["size_lr_mean"] - g["size_lr_std"].fillna(0)),
        (g["size_lr_mean"] + g["size_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_mlp_mean"], label="CLF (MLP)", linestyle="-.")
    ax.fill_between(
        x,
        (g["size_mlp_mean"] - g["size_mlp_std"].fillna(0)),
        (g["size_mlp_mean"] + g["size_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        (g["size_adjF_mean"] - g["size_adjF_std"].fillna(0)),
        (g["size_adjF_mean"] + g["size_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.set_title("Average set size")
    ax.set_ylabel("Set size")

    # =========================
    # Shared x formatting
    # =========================
    for ax in axes:
        ax.set_xlabel(xlab)
        ax.set_xticks(x)
        for tick in ax.get_xticklabels():
            tick.set_rotation(45)
            tick.set_ha("right")

    # --- Single shared legend (better for tight width) ---
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles, labels,
        loc="upper right",
        ncol=1,          # keep compact; try 3 if it still fits
        frameon=False,
        bbox_to_anchor=(1.0, 0.9)
    )

    fig.tight_layout(pad=0.3, w_pad=0.6)

    out_pdf = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}_sidebyside.pdf")
    out_png = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}_sidebyside.png")
    fig.savefig(out_pdf, bbox_inches="tight")
    fig.savefig(out_png, bbox_inches="tight")
    print(f"Saved figure to:\n  {out_pdf}\n  {out_png}")

    plt.show()

    
plot_ablation2(df, cfg)
# Out:
# Using device: cuda
#
# === Simulation 1/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.903, size=11.345 | CLF-MLP: cov=0.898, size=12.693 | AdjF: cov=0.882, size=8.076
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.903, size=9.561 | CLF-MLP: cov=0.905, size=9.800 | AdjF: cov=0.896, size=8.230
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.898, size=8.593 | CLF-MLP: cov=0.900, size=8.855 | AdjF: cov=0.901, size=8.297
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.898, size=8.793 | CLF-MLP: cov=0.900, size=8.367 | AdjF: cov=0.895, size=7.976
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.904, size=8.750 | CLF-MLP: cov=0.911, size=9.030 | AdjF: cov=0.899, size=8.190
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.910, size=8.749 | CLF-MLP: cov=0.908, size=8.320 | AdjF: cov=0.900, size=8.111
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.902, size=8.204 | CLF-MLP: cov=0.902, size=8.077 | AdjF: cov=0.898, size=8.104
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.899, size=8.098 | CLF-MLP: cov=0.905, size=8.351 | AdjF: cov=0.898, size=8.078
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.906, size=8.066 | CLF-MLP: cov=0.905, size=7.729 | AdjF: cov=0.899, size=8.076
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.904, size=7.881 | CLF-MLP: cov=0.905, size=7.735 | AdjF: cov=0.899, size=8.133
#
# === Simulation 2/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.922, size=13.212 | CLF-MLP: cov=0.911, size=13.736 | AdjF: cov=0.893, size=8.018
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.908, size=10.483 | CLF-MLP: cov=0.907, size=10.444 | AdjF: cov=0.894, size=7.969
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.908, size=9.896 | CLF-MLP: cov=0.908, size=9.782 | AdjF: cov=0.894, size=8.053
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.906, size=9.426 | CLF-MLP: cov=0.906, size=9.363 | AdjF: cov=0.897, size=8.034
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.911, size=9.700 | CLF-MLP: cov=0.906, size=8.991 | AdjF: cov=0.897, size=8.010
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.909, size=9.135 | CLF-MLP: cov=0.908, size=8.855 | AdjF: cov=0.897, size=8.081
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.910, size=9.006 | CLF-MLP: cov=0.908, size=8.877 | AdjF: cov=0.896, size=8.069
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.907, size=8.613 | CLF-MLP: cov=0.907, size=8.747 | AdjF: cov=0.896, size=8.023
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.909, size=8.931 | CLF-MLP: cov=0.904, size=8.456 | AdjF: cov=0.898, size=8.077
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.910, size=8.824 | CLF-MLP: cov=0.909, size=8.438 | AdjF: cov=0.896, size=8.012
#
# === Simulation 3/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.902, size=11.795 | CLF-MLP: cov=0.900, size=12.471 | AdjF: cov=0.903, size=8.964
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.898, size=9.644 | CLF-MLP: cov=0.902, size=9.934 | AdjF: cov=0.892, size=8.091
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.906, size=9.655 | CLF-MLP: cov=0.902, size=9.467 | AdjF: cov=0.895, size=8.070
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.904, size=9.571 | CLF-MLP: cov=0.907, size=9.476 | AdjF: cov=0.900, size=8.463
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.910, size=9.223 | CLF-MLP: cov=0.913, size=9.123 | AdjF: cov=0.901, size=8.300
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.906, size=8.688 | CLF-MLP: cov=0.911, size=8.688 | AdjF: cov=0.901, size=8.276
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.909, size=9.053 | CLF-MLP: cov=0.907, size=8.612 | AdjF: cov=0.903, size=8.331
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.906, size=8.430 | CLF-MLP: cov=0.911, size=8.706 | AdjF: cov=0.901, size=8.305
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.904, size=8.068 | CLF-MLP: cov=0.913, size=8.537 | AdjF: cov=0.899, size=8.260
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.905, size=8.095 | CLF-MLP: cov=0.912, size=8.359 | AdjF: cov=0.900, size=8.224
#
# === Simulation 4/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.908, size=12.661 | CLF-MLP: cov=0.904, size=14.253 | AdjF: cov=0.888, size=8.125
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.911, size=11.268 | CLF-MLP: cov=0.911, size=11.996 | AdjF: cov=0.898, size=8.374
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.915, size=11.156 | CLF-MLP: cov=0.912, size=10.905 | AdjF: cov=0.901, size=8.712
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.910, size=10.413 | CLF-MLP: cov=0.911, size=9.781 | AdjF: cov=0.898, size=8.278
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.905, size=9.982 | CLF-MLP: cov=0.909, size=9.874 | AdjF: cov=0.903, size=8.585
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.910, size=9.966 | CLF-MLP: cov=0.906, size=9.606 | AdjF: cov=0.900, size=8.466
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.910, size=9.816 | CLF-MLP: cov=0.910, size=9.702 | AdjF: cov=0.902, size=8.543
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.906, size=9.362 | CLF-MLP: cov=0.905, size=9.003 | AdjF: cov=0.901, size=8.509
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.907, size=9.526 | CLF-MLP: cov=0.908, size=9.083 | AdjF: cov=0.901, size=8.552
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.910, size=9.581 | CLF-MLP: cov=0.908, size=8.941 | AdjF: cov=0.900, size=8.526
#
# === Simulation 5/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.906, size=11.885 | CLF-MLP: cov=0.907, size=12.734 | AdjF: cov=0.879, size=7.363
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.902, size=9.412 | CLF-MLP: cov=0.900, size=9.457 | AdjF: cov=0.887, size=7.804
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.901, size=8.637 | CLF-MLP: cov=0.896, size=8.440 | AdjF: cov=0.891, size=7.809
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.893, size=7.889 | CLF-MLP: cov=0.896, size=8.279 | AdjF: cov=0.892, size=7.901
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.901, size=8.272 | CLF-MLP: cov=0.899, size=7.666 | AdjF: cov=0.892, size=7.697
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.903, size=8.379 | CLF-MLP: cov=0.894, size=7.573 | AdjF: cov=0.891, size=7.671
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.906, size=8.460 | CLF-MLP: cov=0.899, size=7.375 | AdjF: cov=0.892, size=7.758
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.903, size=7.766 | CLF-MLP: cov=0.899, size=7.808 | AdjF: cov=0.894, size=7.781
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.900, size=7.629 | CLF-MLP: cov=0.899, size=7.516 | AdjF: cov=0.892, size=7.710
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.902, size=7.640 | CLF-MLP: cov=0.897, size=7.286 | AdjF: cov=0.893, size=7.722
#
# === Simulation 6/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.899, size=10.103 | CLF-MLP: cov=0.898, size=11.378 | AdjF: cov=0.894, size=7.605
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.911, size=9.878 | CLF-MLP: cov=0.906, size=9.848 | AdjF: cov=0.898, size=7.466
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.911, size=9.247 | CLF-MLP: cov=0.906, size=9.020 | AdjF: cov=0.900, size=7.734
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.909, size=8.367 | CLF-MLP: cov=0.907, size=8.776 | AdjF: cov=0.902, size=7.804
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.910, size=8.601 | CLF-MLP: cov=0.909, size=8.397 | AdjF: cov=0.903, size=7.830
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.912, size=8.229 | CLF-MLP: cov=0.911, size=8.267 | AdjF: cov=0.899, size=7.508
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.909, size=8.131 | CLF-MLP: cov=0.909, size=7.834 | AdjF: cov=0.901, size=7.530
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.913, size=8.168 | CLF-MLP: cov=0.917, size=8.311 | AdjF: cov=0.903, size=7.718
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.911, size=8.053 | CLF-MLP: cov=0.907, size=7.625 | AdjF: cov=0.901, size=7.664
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.913, size=8.014 | CLF-MLP: cov=0.909, size=7.852 | AdjF: cov=0.901, size=7.662
#
# === Simulation 7/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.910, size=12.785 | CLF-MLP: cov=0.910, size=14.836 | AdjF: cov=0.896, size=8.640
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.898, size=10.541 | CLF-MLP: cov=0.905, size=11.210 | AdjF: cov=0.899, size=8.612
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.907, size=10.012 | CLF-MLP: cov=0.907, size=10.166 | AdjF: cov=0.899, size=8.359
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.909, size=9.679 | CLF-MLP: cov=0.904, size=9.637 | AdjF: cov=0.899, size=8.174
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.907, size=9.661 | CLF-MLP: cov=0.905, size=9.322 | AdjF: cov=0.901, size=8.512
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.905, size=9.303 | CLF-MLP: cov=0.903, size=9.170 | AdjF: cov=0.900, size=8.302
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.912, size=9.782 | CLF-MLP: cov=0.909, size=9.314 | AdjF: cov=0.902, size=8.459
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.908, size=9.210 | CLF-MLP: cov=0.907, size=9.048 | AdjF: cov=0.902, size=8.380
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.908, size=8.962 | CLF-MLP: cov=0.908, size=8.894 | AdjF: cov=0.902, size=8.375
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.909, size=8.948 | CLF-MLP: cov=0.910, size=9.031 | AdjF: cov=0.902, size=8.371
#
# === Simulation 8/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.905, size=11.645 | CLF-MLP: cov=0.903, size=13.179 | AdjF: cov=0.890, size=7.771
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.905, size=9.748 | CLF-MLP: cov=0.908, size=10.190 | AdjF: cov=0.892, size=8.005
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.903, size=9.253 | CLF-MLP: cov=0.903, size=8.762 | AdjF: cov=0.893, size=8.027
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.907, size=9.204 | CLF-MLP: cov=0.907, size=9.523 | AdjF: cov=0.896, size=7.859
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.905, size=8.869 | CLF-MLP: cov=0.907, size=8.422 | AdjF: cov=0.895, size=7.895
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.908, size=8.695 | CLF-MLP: cov=0.906, size=8.559 | AdjF: cov=0.893, size=7.737
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.907, size=8.384 | CLF-MLP: cov=0.906, size=8.329 | AdjF: cov=0.896, size=7.875
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.905, size=8.158 | CLF-MLP: cov=0.905, size=8.027 | AdjF: cov=0.894, size=7.842
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.909, size=8.556 | CLF-MLP: cov=0.908, size=8.131 | AdjF: cov=0.895, size=7.859
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.908, size=8.100 | CLF-MLP: cov=0.909, size=7.975 | AdjF: cov=0.895, size=7.849
#
# === Simulation 9/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.902, size=10.905 | CLF-MLP: cov=0.905, size=12.156 | AdjF: cov=0.892, size=8.064
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.898, size=9.591 | CLF-MLP: cov=0.905, size=9.617 | AdjF: cov=0.892, size=7.449
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.900, size=9.291 | CLF-MLP: cov=0.902, size=8.851 | AdjF: cov=0.896, size=7.622
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.898, size=9.067 | CLF-MLP: cov=0.900, size=8.926 | AdjF: cov=0.896, size=7.735
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.906, size=9.106 | CLF-MLP: cov=0.903, size=8.724 | AdjF: cov=0.896, size=7.691
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.900, size=8.764 | CLF-MLP: cov=0.902, size=8.358 | AdjF: cov=0.898, size=7.865
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.901, size=8.452 | CLF-MLP: cov=0.901, size=8.236 | AdjF: cov=0.897, size=7.734
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.899, size=8.288 | CLF-MLP: cov=0.905, size=8.346 | AdjF: cov=0.896, size=7.718
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.900, size=8.124 | CLF-MLP: cov=0.901, size=8.038 | AdjF: cov=0.898, size=7.755
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.897, size=8.128 | CLF-MLP: cov=0.901, size=8.259 | AdjF: cov=0.898, size=7.757
#
# === Simulation 10/10 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 2/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 3/4] training ResNet-18...
#   epoch 25/150
#   epoch 50/150
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     [View 4/4] training ResNet-18...
#   epoch 75/150
#   epoch 100/150
#   epoch 125/150
#   epoch 150/150
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.902, size=12.006 | CLF-MLP: cov=0.906, size=12.782 | AdjF: cov=0.880, size=7.458
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.910, size=10.318 | CLF-MLP: cov=0.902, size=10.342 | AdjF: cov=0.887, size=7.201
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.907, size=9.752 | CLF-MLP: cov=0.904, size=9.050 | AdjF: cov=0.894, size=7.650
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.903, size=9.608 | CLF-MLP: cov=0.899, size=8.546 | AdjF: cov=0.898, size=7.765
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.907, size=9.002 | CLF-MLP: cov=0.898, size=8.153 | AdjF: cov=0.899, size=7.907
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.906, size=9.272 | CLF-MLP: cov=0.906, size=8.102 | AdjF: cov=0.899, size=7.845
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.900, size=8.264 | CLF-MLP: cov=0.903, size=7.926 | AdjF: cov=0.901, size=7.982
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.902, size=8.208 | CLF-MLP: cov=0.904, size=7.917 | AdjF: cov=0.902, size=7.923
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.905, size=8.382 | CLF-MLP: cov=0.904, size=7.871 | AdjF: cov=0.901, size=7.846
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.906, size=8.198 | CLF-MLP: cov=0.903, size=7.824 | AdjF: cov=0.901, size=7.852
#
# Saved raw results to: cifar100_ablation_outputs2/cifar100_ablation_ntfrac_results.csv
# Saved aggregated table to: cifar100_ablation_outputs2/cifar100_ablation_ntfrac_agg_K4.csv
# Saved figure to:
#   cifar100_ablation_outputs2/cifar100_ablation_ntfrac_cifar100_K4.pdf
#   cifar100_ablation_outputs2/cifar100_ablation_ntfrac_cifar100_K4.png
# Saved aggregated table to: cifar100_ablation_outputs2/cifar100_ablation_ntfrac_agg_K4.csv
# Saved figure to:
#   cifar100_ablation_outputs2/cifar100_ablation_ntfrac_cifar100_K4_sidebyside.pdf
#   cifar100_ablation_outputs2/cifar100_ablation_ntfrac_cifar100_K4_sidebyside.png
