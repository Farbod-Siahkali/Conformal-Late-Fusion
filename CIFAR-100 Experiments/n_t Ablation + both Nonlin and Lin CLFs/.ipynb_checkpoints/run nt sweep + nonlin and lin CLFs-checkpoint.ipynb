# %%
"""
CIFAR-100 ablation study (matched to your MAIN CIFAR-100 script):

Goal:
  Sweep fusion-train size n_t as a fraction of baseline n_t (fusion-train split),
  and plot (1) coverage and (2) average set size vs n_t fraction, for K=4.

This version answers BOTH reviewer points in ONE experiment:
  - Small-sample / 3-way split sensitivity: vary n_t via nt_frac sweep
  - Fusion architecture ablation: compare CLF fusion map phi_theta as
        (A) multinomial Logistic Regression  on [p;prob]
        (B) 2-hidden-layer MLP              on [p;prob]
    plus baseline Adjusted Fisher (depends on subset train p-values)

Methods plotted:
  - CLF (LR)   : LogisticRegression on [p;prob] + stage-3 conformal recalibration
  - CLF (MLP)  : 2-layer MLP on [p;prob] + stage-3 conformal recalibration
  - Adjusted Fisher (moment-matched Fisher) baseline

MATCHING GUARANTEE (practically):
  For nt_frac=1.0 and K=4, CLF(LR) and AdjF should match your CIFAR-100 experiment’s
  K=4 behavior (up to stochasticity), because:
    (i) SAME per-view model + SAME train_model,
    (ii) SAME data splits + seeds,
    (iii) SAME feature construction and conformalization.

Outputs:
  - cifar100_ablation_ntfrac_results.csv
  - cifar100_ablation_ntfrac_agg_K4.csv
  - cifar100_ablation_ntfrac_cifar100_K4.pdf  (and .png)
"""

from __future__ import annotations

import os
import warnings
from dataclasses import dataclass
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
from scipy.stats import chi2

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from torchvision.transforms import Resize

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# =========================
# Plot style (NO seaborn)
# =========================
import matplotlib as mpl
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

try:
    import scienceplots  # noqa: F401
    plt.style.use(["science", "no-latex"])
except Exception as e:
    print("[WARN] scienceplots not found or style failed; using default matplotlib style.", e)

mpl.rcParams["pdf.fonttype"] = 42
mpl.rcParams["ps.fonttype"] = 42
mpl.rcParams.update(
    {
        "font.size": 8,
        "axes.titlesize": 9,
        "axes.labelsize": 8,
        "xtick.labelsize": 7,
        "ytick.labelsize": 7,
        "legend.fontsize": 6,
        "lines.linewidth": 1.0,
        "axes.linewidth": 0.5,
    }
)

# =============================================================================
# Config (MATCH your CIFAR-100 experiment params)
# =============================================================================

@dataclass
class AblationConfig100:
    # core (match CIFAR-100 experiment)
    alpha: float = 0.1
    num_classes: int = 100
    num_simulations: int = 5

    # training (match CIFAR-100 experiment)
    epochs_per_view: int = 100
    lr: float = 1e-3
    batch_size: int = 8192
    max_iter_lr: int = 1000
    train_seed_base: int = 41

    # data split fractions (match CIFAR-100 experiment)
    train_frac: float = 0.5
    cal_frac_of_temp: float = 0.3
    fuse_train_frac_of_rest: float = 0.7

    # Ablation target
    K_target: int = 4

    # Ablation sweep
    nt_fracs: Tuple[float, ...] = tuple(np.round(np.linspace(0.1, 1.0, 10), 2))

    # Fusion MLP (2-layer) hyperparams
    fusion_epochs: int = 50
    fusion_hidden1: int = 512
    fusion_hidden2: int = 512
    fusion_weight_decay: float = 1e-4
    fusion_batch_size: int = 4096  # separate from per-view batch size for stability

    # Output
    out_dir: str = "cifar100_ablation_outputs"


# =============================================================================
# Torch / Data (match CIFAR-100 experiment)
# =============================================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

transform = transforms.Compose([transforms.ToTensor()])

train_dataset = datasets.CIFAR100(root="./data", train=True, download=True, transform=transform)
test_dataset  = datasets.CIFAR100(root="./data", train=False, download=True, transform=transform)

X_train_full = train_dataset.data.astype(np.float32) / 255.0
Y_train_full = np.array(train_dataset.targets, dtype=int)
X_test_full  = test_dataset.data.astype(np.float32) / 255.0
Y_test_full  = np.array(test_dataset.targets, dtype=int)


# =============================================================================
# Multi-view (patch) utilities (match CIFAR-100 experiment)
# =============================================================================

def split_image_into_k_patches(image: torch.Tensor, k: int) -> List[torch.Tensor]:
    C, H, W = image.shape
    if k == 4:
        patches = []
        for i in range(2):
            for j in range(2):
                patch = image[:, i * 16 : (i + 1) * 16, j * 16 : (j + 1) * 16]
                patches.append(patch)
        return patches
    else:
        base_width = W // k
        remainder = W % k
        patches, start = [], 0
        for idx in range(k):
            width = base_width + (1 if idx < remainder else 0)
            patch = image[:, :, start : start + width]
            patches.append(patch)
            start += width
        return patches


class PatchesDataset(torch.utils.data.Dataset):
    def __init__(self, images: np.ndarray, labels: np.ndarray, k: int, view: int):
        self.images = images
        self.labels = labels
        self.k = k
        self.view = view
        self.resize = Resize((32, 32))  # match your CIFAR-100 code

    def __len__(self) -> int:
        return len(self.labels)

    def __getitem__(self, idx: int):
        img = self.images[idx].transpose((2, 0, 1))
        img = torch.tensor(img, dtype=torch.float32)
        patches = split_image_into_k_patches(img, self.k)
        patch = patches[self.view]
        patch = self.resize(patch)
        y = int(self.labels[idx])
        return patch, y


# =============================================================================
# EfficientNet-B0 per view (match CIFAR-100 experiment)
# =============================================================================

class PredictorCNN(nn.Module):
    def __init__(self, num_classes: int = 100):
        super().__init__()
        self.model = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
        in_features = self.model.classifier[1].in_features
        self.model.classifier[1] = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)


def train_model(model: nn.Module, train_loader, num_epochs: int, lr: float):
    # match your CIFAR-100 code
    crit = nn.CrossEntropyLoss()
    opt = optim.Adam(model.parameters(), lr=lr)
    model.to(device)
    for ep in range(num_epochs):
        model.train()
        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = torch.tensor(yb, dtype=torch.long, device=device)
            opt.zero_grad()
            loss = crit(model(xb), yb)
            loss.backward()
            opt.step()
        if (ep + 1) % 25 == 0:
            print(f"  epoch {ep+1}/{num_epochs}")
    return model


# =============================================================================
# Conformal utilities (match CIFAR-100 experiment)
# =============================================================================

def compute_nonconformity_scores(model: nn.Module, loader) -> Tuple[np.ndarray, np.ndarray]:
    model.eval()
    scores, labels = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            logits = model(xb)
            probs = F.softmax(logits, dim=1)
            idx = torch.arange(probs.size(0), device=probs.device)
            true_p = probs[idx, torch.tensor(yb, dtype=torch.long, device=probs.device)]
            s = (1.0 - true_p).detach().cpu().numpy()
            scores.extend(s)
            labels.extend(yb.numpy())
    return np.asarray(scores, float), np.asarray(labels, int)


def classwise_scores(scores: np.ndarray, labels: np.ndarray, L: int) -> Dict[int, np.ndarray]:
    out = {c: [] for c in range(L)}
    for s, y in zip(scores, labels):
        out[int(y)].append(float(s))
    return {c: np.asarray(v, float) for c, v in out.items()}


def per_view_pvalues_and_probs(
    model: nn.Module, class_scores: Dict[int, np.ndarray], loader, L: int
) -> Tuple[np.ndarray, np.ndarray]:
    model.eval()
    probs_all = []
    with torch.no_grad():
        for xb, _ in loader:
            xb = xb.to(device)
            logits = model(xb)
            probs = F.softmax(logits, dim=1).detach().cpu().numpy()
            probs_all.append(probs)
    probs_all = np.vstack(probs_all)  # (n, L)

    n = probs_all.shape[0]
    pvals = np.zeros((n, L), dtype=float)
    for y in range(L):
        cal = class_scores.get(y, np.array([], dtype=float))
        if cal.size == 0:
            pvals[:, y] = 1.0
        else:
            s_test = 1.0 - probs_all[:, y]
            counts = np.sum(cal[:, None] >= s_test[None, :], axis=0)
            pvals[:, y] = (1.0 + counts) / (len(cal) + 1.0)
    return pvals, probs_all


# =============================================================================
# Fusion + baselines (match CIFAR-100 experiment)
# =============================================================================

def build_fusion_features(pvals_list: List[np.ndarray], probs_list: List[np.ndarray]) -> np.ndarray:
    blocks = [np.hstack([pvals_list[k], probs_list[k]]) for k in range(len(pvals_list))]
    return np.hstack(blocks)


def fisher_fusion(P_all: np.ndarray) -> np.ndarray:
    eps = 1e-12
    p = np.clip(P_all, eps, 1.0)
    T = -2 * np.sum(np.log(p), axis=0)
    df = 2 * P_all.shape[0]
    return 1 - chi2.cdf(T, df=df)


def adjusted_fisher_fusion(P_train: np.ndarray, y_train: np.ndarray, P_test: np.ndarray, L: int) -> np.ndarray:
    K, _, _ = P_train.shape
    n_test = P_test.shape[1]
    eps = 1e-12
    out = np.zeros((n_test, L), dtype=float)
    for y in range(L):
        idx = np.where(y_train == y)[0]
        if idx.size < 5:
            out[:, y] = fisher_fusion(P_test)[:, y]
            continue
        P_cls = np.clip(P_train[:, idx, y], eps, 1.0)
        W = -2 * np.log(P_cls)
        Wc = W - W.mean(axis=1, keepdims=True)
        Sigma = (Wc @ Wc.T) / max(W.shape[1] - 1, 1)
        var_T = np.sum(Sigma)
        if not np.isfinite(var_T) or var_T <= 0:
            var_T = 4 * K
        f_y = (8.0 * K * K) / var_T
        c_y = var_T / (4 * K)

        P_t = np.clip(P_test[:, :, y], eps, 1.0)
        T_t = -2 * np.sum(np.log(P_t), axis=0)
        out[:, y] = 1 - chi2.cdf(T_t / c_y, df=f_y)
    return out


def fused_class_cal_scores(y_cal: np.ndarray, fused_probs_cal: np.ndarray, L: int) -> Dict[int, np.ndarray]:
    s = 1.0 - fused_probs_cal[np.arange(len(y_cal)), y_cal]
    out = {c: [] for c in range(L)}
    for sc, yy in zip(s, y_cal):
        out[int(yy)].append(float(sc))
    return {c: np.asarray(v, float) for c, v in out.items()}


def fused_p_values_from_cal(fused_probs: np.ndarray, cal_class_scores: Dict[int, np.ndarray]) -> np.ndarray:
    n, L = fused_probs.shape
    out = np.zeros((n, L), dtype=float)
    for y in range(L):
        cal = cal_class_scores.get(y, np.array([], dtype=float))
        if cal.size == 0:
            out[:, y] = 1.0
        else:
            s_test = 1.0 - fused_probs[:, y]
            counts = np.sum(cal[:, None] >= s_test[None, :], axis=0)
            out[:, y] = (1.0 + counts) / (len(cal) + 1.0)
    return out


def evaluate_sets(P: np.ndarray, y_true: np.ndarray, alpha: float) -> Tuple[float, float]:
    C = (P > alpha)
    cov = float(np.mean(C[np.arange(len(y_true)), y_true]))
    size = float(np.mean(C.sum(axis=1)))
    return cov, size


# =============================================================================
# Fusion MLP (2 hidden layers) + training/predict
# =============================================================================

class FusionMLP(nn.Module):
    def __init__(self, d_in: int, d_h1: int, d_h2: int, d_out: int):
        super().__init__()
        self.fc1 = nn.Linear(d_in, d_h1)
        self.fc2 = nn.Linear(d_h1, d_h2)
        self.fc3 = nn.Linear(d_h2, d_out)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


def set_all_seeds(seed: int):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False


def train_fusion_mlp(
    X: np.ndarray,
    y: np.ndarray,
    d_in: int,
    L: int,
    seed: int,
    epochs: int,
    lr: float,
    weight_decay: float,
    batch_size: int,
    hidden1: int,
    hidden2: int,
) -> FusionMLP:
    set_all_seeds(seed)
    model = FusionMLP(d_in, hidden1, hidden2, L).to(device)
    opt = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    crit = nn.CrossEntropyLoss()

    X_t = torch.tensor(X, dtype=torch.float32)
    y_t = torch.tensor(y, dtype=torch.long)
    ds = torch.utils.data.TensorDataset(X_t, y_t)
    dl = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True)

    model.train()
    for _ in range(epochs):
        for xb, yb in dl:
            xb = xb.to(device)
            yb = yb.to(device)
            opt.zero_grad()
            loss = crit(model(xb), yb)
            loss.backward()
            opt.step()
    return model


@torch.no_grad()
def fusion_mlp_predict_proba(model: FusionMLP, X: np.ndarray, batch_size: int = 8192) -> np.ndarray:
    model.eval()
    X_t = torch.tensor(X, dtype=torch.float32)
    dl = torch.utils.data.DataLoader(X_t, batch_size=batch_size, shuffle=False)
    probs = []
    for xb in dl:
        xb = xb.to(device)
        logits = model(xb)
        probs.append(F.softmax(logits, dim=1).detach().cpu().numpy())
    return np.vstack(probs)


# =============================================================================
# Subsampling helper (stratified)
# =============================================================================

def stratified_subsample_indices(y: np.ndarray, n_sub: int, seed: int) -> np.ndarray:
    n = len(y)
    n_sub = int(max(1, min(n_sub, n)))
    idx_all = np.arange(n, dtype=int)
    if n_sub >= n:
        return idx_all
    idx_sub, _ = train_test_split(idx_all, train_size=n_sub, stratify=y, random_state=seed)
    return np.asarray(idx_sub, dtype=int)


# =============================================================================
# Main ablation (CIFAR-100, K=4): CLF(LR) vs CLF(MLP) vs AdjF
# =============================================================================

def run_ablation(cfg: AblationConfig100) -> pd.DataFrame:
    os.makedirs(cfg.out_dir, exist_ok=True)
    rows = []

    for sim in range(cfg.num_simulations):
        print(f"\n=== Simulation {sim+1}/{cfg.num_simulations} ===")
        seed = cfg.train_seed_base + sim

        # EXACT splits as your CIFAR-100 experiment
        X_trP, X_tmp, y_trP, y_tmp = train_test_split(
            X_train_full,
            Y_train_full,
            test_size=1 - cfg.train_frac,
            stratify=Y_train_full,
            random_state=seed,
        )
        X_cal, X_rest, y_cal, y_rest = train_test_split(
            X_tmp,
            y_tmp,
            test_size=1 - cfg.cal_frac_of_temp,
            stratify=y_tmp,
            random_state=seed,
        )
        X_fuse_tr_full, X_fuse_cal, y_fuse_tr_full, y_fuse_cal = train_test_split(
            X_rest,
            y_rest,
            test_size=1 - cfg.fuse_train_frac_of_rest,
            stratify=y_rest,
            random_state=seed,
        )

        X_te, y_te = X_test_full, Y_test_full
        K = cfg.K_target
        num_views = 4  # K=4 special-case

        print(f"\n  -> K = {K} (ablation target)")

        # loaders per view
        loaders = {}
        for v in range(num_views):
            tr_loader = torch.utils.data.DataLoader(
                PatchesDataset(X_trP, y_trP, K, v),
                batch_size=cfg.batch_size,
                shuffle=True,
            )
            cal_loader = torch.utils.data.DataLoader(
                PatchesDataset(X_cal, y_cal, K, v),
                batch_size=cfg.batch_size,
                shuffle=False,
            )
            ftr_loader = torch.utils.data.DataLoader(
                PatchesDataset(X_fuse_tr_full, y_fuse_tr_full, K, v),
                batch_size=cfg.batch_size,
                shuffle=False,
            )
            fcal_loader = torch.utils.data.DataLoader(
                PatchesDataset(X_fuse_cal, y_fuse_cal, K, v),
                batch_size=cfg.batch_size,
                shuffle=False,
            )
            te_loader = torch.utils.data.DataLoader(
                PatchesDataset(X_te, y_te, K, v),
                batch_size=cfg.batch_size,
                shuffle=False,
            )
            loaders[v] = dict(train=tr_loader, cal=cal_loader, ftr=ftr_loader, fcal=fcal_loader, te=te_loader)

        # Train per-view predictors (match CIFAR-100 experiment)
        models: List[PredictorCNN] = []
        cal_classwise: List[Dict[int, np.ndarray]] = []
        for v in range(num_views):
            print(f"    [View {v+1}/{num_views}] training...")
            m = PredictorCNN(num_classes=cfg.num_classes)
            m = train_model(m, loaders[v]["train"], num_epochs=cfg.epochs_per_view, lr=cfg.lr)
            models.append(m)

            sc, lab = compute_nonconformity_scores(m, loaders[v]["cal"])
            cal_classwise.append(classwise_scores(sc, lab, cfg.num_classes))

        # Per-view p/probs for fusion train full, cal2, and test
        pv_tr_full, pr_tr_full = [], []
        pv_cal2, pr_cal2 = [], []
        pv_te, pr_te = [], []
        for v in range(num_views):
            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["ftr"], cfg.num_classes)
            pv_tr_full.append(p)
            pr_tr_full.append(pr)

            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["fcal"], cfg.num_classes)
            pv_cal2.append(p)
            pr_cal2.append(pr)

            p, pr = per_view_pvalues_and_probs(models[v], cal_classwise[v], loaders[v]["te"], cfg.num_classes)
            pv_te.append(p)
            pr_te.append(pr)

        # Fixed test p-stack for baselines
        P_test = np.stack(pv_te, axis=0)  # (K, n_test, L)

        # Fixed features for cal2/test (cal2 remains full across nt_fracs)
        X_cal2_feat = build_fusion_features(pv_cal2, pr_cal2)
        X_test_feat = build_fusion_features(pv_te, pr_te)

        n_t_full = len(y_fuse_tr_full)

        # Optional: free per-view models from GPU before fusion sweeps to reduce VRAM
        # (comment out if you prefer)
        for m in models:
            m.to("cpu")
        torch.cuda.empty_cache()

        for frac in cfg.nt_fracs:
            n_sub = int(round(frac * n_t_full))
            idx_sub = stratified_subsample_indices(
                y_fuse_tr_full, n_sub, seed=seed + int(frac * 1000)
            )

            y_tr_sub = y_fuse_tr_full[idx_sub]
            pv_tr_sub = [pv[idx_sub] for pv in pv_tr_full]
            pr_tr_sub = [pr[idx_sub] for pr in pr_tr_full]

            # Features for fusion training subset
            X_ftr_sub = build_fusion_features(pv_tr_sub, pr_tr_sub)
            d_in = X_ftr_sub.shape[1]

            # -----------------------------
            # (A) CLF (LR) on [p;prob] trained on subset; conformalize on full cal2
            # -----------------------------
            fusion_lr = LogisticRegression(
                max_iter=cfg.max_iter_lr,
                multi_class="multinomial",
                solver="lbfgs",
                random_state=seed,
            )
            fusion_lr.fit(X_ftr_sub, y_tr_sub)

            fused_probs_cal2_lr = fusion_lr.predict_proba(X_cal2_feat)
            fused_cal_scores_lr = fused_class_cal_scores(y_fuse_cal, fused_probs_cal2_lr, cfg.num_classes)

            fused_probs_test_lr = fusion_lr.predict_proba(X_test_feat)
            P_cf_lr = fused_p_values_from_cal(fused_probs_test_lr, fused_cal_scores_lr)

            cov_lr, size_lr = evaluate_sets(P_cf_lr, y_te, cfg.alpha)

            # -----------------------------
            # (B) CLF (MLP) on [p;prob] trained on subset; conformalize on full cal2
            # -----------------------------
            fusion_mlp = train_fusion_mlp(
                X=X_ftr_sub,
                y=y_tr_sub,
                d_in=d_in,
                L=cfg.num_classes,
                seed=seed + 12345 + int(frac * 1000),  # distinct but deterministic
                epochs=cfg.fusion_epochs,
                lr=cfg.lr,  # keep same lr scale as your scripts
                weight_decay=cfg.fusion_weight_decay,
                batch_size=cfg.fusion_batch_size,
                hidden1=cfg.fusion_hidden1,
                hidden2=cfg.fusion_hidden2,
            )

            fused_probs_cal2_mlp = fusion_mlp_predict_proba(fusion_mlp, X_cal2_feat, batch_size=cfg.fusion_batch_size)
            fused_cal_scores_mlp = fused_class_cal_scores(y_fuse_cal, fused_probs_cal2_mlp, cfg.num_classes)

            fused_probs_test_mlp = fusion_mlp_predict_proba(fusion_mlp, X_test_feat, batch_size=cfg.fusion_batch_size)
            P_cf_mlp = fused_p_values_from_cal(fused_probs_test_mlp, fused_cal_scores_mlp)

            cov_mlp, size_mlp = evaluate_sets(P_cf_mlp, y_te, cfg.alpha)

            # -----------------------------
            # (C) Adjusted Fisher baseline (depends on subset)
            # -----------------------------
            P_train_sub = np.stack(pv_tr_sub, axis=0)
            P_adjF = adjusted_fisher_fusion(P_train_sub, y_tr_sub, P_test, cfg.num_classes)
            cov_adjF, size_adjF = evaluate_sets(P_adjF, y_te, cfg.alpha)

            rows.append(
                dict(
                    sim=sim,
                    seed=seed,
                    K=K,
                    alpha=cfg.alpha,
                    nt_frac=float(frac),
                    nt_sub=int(len(idx_sub)),
                    nt_full=int(n_t_full),
                    cov_clf_lr=float(cov_lr),
                    size_clf_lr=float(size_lr),
                    cov_clf_mlp=float(cov_mlp),
                    size_clf_mlp=float(size_mlp),
                    cov_adjF=float(cov_adjF),
                    size_adjF=float(size_adjF),
                )
            )

            print(
                f"    nt_frac={frac:.2f} (n={len(idx_sub):5d}) | "
                f"CLF-LR: cov={cov_lr:.3f}, size={size_lr:.3f} | "
                f"CLF-MLP: cov={cov_mlp:.3f}, size={size_mlp:.3f} | "
                f"AdjF: cov={cov_adjF:.3f}, size={size_adjF:.3f}"
            )

    df = pd.DataFrame(rows)
    out_csv = os.path.join(cfg.out_dir, "cifar100_ablation_ntfrac_results.csv")
    df.to_csv(out_csv, index=False)
    print(f"\nSaved raw results to: {out_csv}")
    return df


def plot_ablation(df: pd.DataFrame, cfg: AblationConfig100):
    g = df.groupby("nt_frac").agg(
        cov_lr_mean=("cov_clf_lr", "mean"),
        cov_lr_std=("cov_clf_lr", "std"),
        size_lr_mean=("size_clf_lr", "mean"),
        size_lr_std=("size_clf_lr", "std"),
        cov_mlp_mean=("cov_clf_mlp", "mean"),
        cov_mlp_std=("cov_clf_mlp", "std"),
        size_mlp_mean=("size_clf_mlp", "mean"),
        size_mlp_std=("size_clf_mlp", "std"),
        cov_adjF_mean=("cov_adjF", "mean"),
        cov_adjF_std=("cov_adjF", "std"),
        size_adjF_mean=("size_adjF", "mean"),
        size_adjF_std=("size_adjF", "std"),
        nt_sub_mean=("nt_sub", "mean"),
    ).reset_index().sort_values("nt_frac")

    out_agg = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_agg_K{cfg.K_target}.csv")
    g.to_csv(out_agg, index=False)
    print(f"Saved aggregated table to: {out_agg}")

    x = g["nt_frac"].to_numpy()
    xlab = r"Fusion-train fraction $n_{\mathrm{fuse}} / n_t$"

    fig, axes = plt.subplots(2, 1, figsize=(3.35, 3.10), dpi=300, sharex=True)

    # -------------------------
    # Coverage
    # -------------------------
    ax = axes[0]
    ax.plot(x, 100.0 * g["cov_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        100.0 * (g["cov_lr_mean"] - g["cov_lr_std"].fillna(0)),
        100.0 * (g["cov_lr_mean"] + g["cov_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_mlp_mean"], label="CLF (2-layer MLP)", linestyle="-.")
    ax.fill_between(
        x,
        100.0 * (g["cov_mlp_mean"] - g["cov_mlp_std"].fillna(0)),
        100.0 * (g["cov_mlp_mean"] + g["cov_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, 100.0 * g["cov_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        100.0 * (g["cov_adjF_mean"] - g["cov_adjF_std"].fillna(0)),
        100.0 * (g["cov_adjF_mean"] + g["cov_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.axhline(100.0 * (1.0 - cfg.alpha), linestyle=":", linewidth=0.8, label=r"Target $1-\alpha$")
    ax.set_ylabel("Coverage (%)")
    ax.set_title(r"CIFAR-100 (K=4): Coverage vs $n_{\mathrm{fuse}}/n_t$")
    ax.set_ylim(100.0 * (1.0 - cfg.alpha) - 5.0, 100.0 * (1.0 - cfg.alpha) + 5.0)
    ax.legend(frameon=False, ncol=2)

    # -------------------------
    # Set size
    # -------------------------
    ax = axes[1]
    ax.plot(x, g["size_lr_mean"], label="CLF (LR)")
    ax.fill_between(
        x,
        (g["size_lr_mean"] - g["size_lr_std"].fillna(0)),
        (g["size_lr_mean"] + g["size_lr_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_mlp_mean"], label="CLF (2-layer MLP)", linestyle="-.")
    ax.fill_between(
        x,
        (g["size_mlp_mean"] - g["size_mlp_std"].fillna(0)),
        (g["size_mlp_mean"] + g["size_mlp_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.plot(x, g["size_adjF_mean"], label="Adjusted Fisher", linestyle="--")
    ax.fill_between(
        x,
        (g["size_adjF_mean"] - g["size_adjF_std"].fillna(0)),
        (g["size_adjF_mean"] + g["size_adjF_std"].fillna(0)),
        alpha=0.2,
        linewidth=0.0,
    )

    ax.set_xlabel(xlab)
    ax.set_ylabel("Avg. set size")
    ax.set_title(r"CIFAR-100 (K=4): Set size vs $n_{\mathrm{fuse}}/n_t$")
    ax.legend(frameon=False, ncol=2)

    ax.set_xticks(x)
    for tick in ax.get_xticklabels():
        tick.set_rotation(45)
        tick.set_ha("right")

    fig.tight_layout()

    out_pdf = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}.pdf")
    out_png = os.path.join(cfg.out_dir, f"cifar100_ablation_ntfrac_cifar100_K{cfg.K_target}.png")
    fig.savefig(out_pdf, bbox_inches="tight")
    fig.savefig(out_png, bbox_inches="tight")
    print(f"Saved figure to:\n  {out_pdf}\n  {out_png}")

    plt.show()


cfg = AblationConfig100()
df = run_ablation(cfg)
plot_ablation(df, cfg)
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# === Simulation 1/5 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 2/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 3/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 4/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.903, size=16.715 | CLF-MLP: cov=0.906, size=18.184 | AdjF: cov=0.894, size=11.960
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.900, size=13.748 | CLF-MLP: cov=0.903, size=14.517 | AdjF: cov=0.892, size=11.109
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.906, size=14.567 | CLF-MLP: cov=0.901, size=13.634 | AdjF: cov=0.900, size=11.478
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.900, size=13.079 | CLF-MLP: cov=0.906, size=13.187 | AdjF: cov=0.900, size=11.547
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.901, size=12.801 | CLF-MLP: cov=0.904, size=12.957 | AdjF: cov=0.899, size=11.480
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.904, size=12.439 | CLF-MLP: cov=0.906, size=12.002 | AdjF: cov=0.900, size=11.212
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.899, size=12.149 | CLF-MLP: cov=0.899, size=11.719 | AdjF: cov=0.901, size=11.409
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.902, size=12.070 | CLF-MLP: cov=0.900, size=11.707 | AdjF: cov=0.902, size=11.446
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.901, size=12.156 | CLF-MLP: cov=0.900, size=11.366 | AdjF: cov=0.901, size=11.447
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.899, size=12.127 | CLF-MLP: cov=0.901, size=11.276 | AdjF: cov=0.901, size=11.437
#
# === Simulation 2/5 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 2/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 3/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 4/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.904, size=16.677 | CLF-MLP: cov=0.910, size=18.627 | AdjF: cov=0.894, size=11.169
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.909, size=14.858 | CLF-MLP: cov=0.908, size=15.064 | AdjF: cov=0.898, size=11.385
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.909, size=14.593 | CLF-MLP: cov=0.907, size=13.775 | AdjF: cov=0.901, size=11.406
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.913, size=13.926 | CLF-MLP: cov=0.910, size=13.411 | AdjF: cov=0.901, size=11.357
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.901, size=13.286 | CLF-MLP: cov=0.906, size=13.151 | AdjF: cov=0.904, size=11.617
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.911, size=13.701 | CLF-MLP: cov=0.904, size=12.097 | AdjF: cov=0.904, size=11.599
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.906, size=12.711 | CLF-MLP: cov=0.905, size=12.079 | AdjF: cov=0.905, size=11.652
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.905, size=13.099 | CLF-MLP: cov=0.902, size=11.704 | AdjF: cov=0.904, size=11.537
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.907, size=12.945 | CLF-MLP: cov=0.908, size=12.447 | AdjF: cov=0.904, size=11.478
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.909, size=12.736 | CLF-MLP: cov=0.901, size=11.691 | AdjF: cov=0.903, size=11.473
#
# === Simulation 3/5 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 2/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 3/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 4/4] training...
#   epoch 50/75
#   epoch 75/75
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.902, size=17.111 | CLF-MLP: cov=0.903, size=17.549 | AdjF: cov=0.890, size=11.156
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.904, size=14.101 | CLF-MLP: cov=0.903, size=15.124 | AdjF: cov=0.896, size=11.500
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.914, size=14.364 | CLF-MLP: cov=0.905, size=13.957 | AdjF: cov=0.900, size=11.534
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.910, size=13.633 | CLF-MLP: cov=0.907, size=13.562 | AdjF: cov=0.901, size=11.515
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.906, size=13.710 | CLF-MLP: cov=0.906, size=13.574 | AdjF: cov=0.901, size=11.450
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.909, size=13.334 | CLF-MLP: cov=0.904, size=12.065 | AdjF: cov=0.902, size=11.598
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.907, size=13.359 | CLF-MLP: cov=0.905, size=12.598 | AdjF: cov=0.902, size=11.559
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.907, size=12.848 | CLF-MLP: cov=0.907, size=12.373 | AdjF: cov=0.904, size=11.761
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.902, size=12.502 | CLF-MLP: cov=0.907, size=12.186 | AdjF: cov=0.903, size=11.612
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.903, size=12.141 | CLF-MLP: cov=0.906, size=11.905 | AdjF: cov=0.903, size=11.584
#
# === Simulation 4/5 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 2/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 3/4] training...
#   epoch 75/75
#     [View 4/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.918, size=17.987 | CLF-MLP: cov=0.913, size=19.760 | AdjF: cov=0.890, size=11.186
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.918, size=16.169 | CLF-MLP: cov=0.906, size=15.626 | AdjF: cov=0.894, size=11.524
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.912, size=15.605 | CLF-MLP: cov=0.914, size=14.750 | AdjF: cov=0.891, size=11.263
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.917, size=14.789 | CLF-MLP: cov=0.916, size=14.114 | AdjF: cov=0.899, size=11.518
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.919, size=14.489 | CLF-MLP: cov=0.915, size=14.016 | AdjF: cov=0.897, size=11.322
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.920, size=14.884 | CLF-MLP: cov=0.914, size=13.376 | AdjF: cov=0.900, size=11.565
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.920, size=14.349 | CLF-MLP: cov=0.911, size=13.230 | AdjF: cov=0.899, size=11.521
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.915, size=13.800 | CLF-MLP: cov=0.913, size=12.632 | AdjF: cov=0.901, size=11.476
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.915, size=13.681 | CLF-MLP: cov=0.912, size=12.886 | AdjF: cov=0.900, size=11.515
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.917, size=13.685 | CLF-MLP: cov=0.914, size=12.664 | AdjF: cov=0.899, size=11.446
#
# === Simulation 5/5 ===
#
#   -> K = 4 (ablation target)
#     [View 1/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 2/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 3/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     [View 4/4] training...
#   epoch 25/75
#   epoch 50/75
#   epoch 75/75
#     nt_frac=0.10 (n= 1225) | CLF-LR: cov=0.905, size=16.357 | CLF-MLP: cov=0.907, size=18.428 | AdjF: cov=0.886, size=11.158
#     nt_frac=0.20 (n= 2450) | CLF-LR: cov=0.911, size=15.310 | CLF-MLP: cov=0.907, size=15.747 | AdjF: cov=0.888, size=11.054
#     nt_frac=0.30 (n= 3675) | CLF-LR: cov=0.911, size=13.923 | CLF-MLP: cov=0.907, size=13.762 | AdjF: cov=0.895, size=11.575
#     nt_frac=0.40 (n= 4900) | CLF-LR: cov=0.914, size=13.712 | CLF-MLP: cov=0.903, size=12.877 | AdjF: cov=0.894, size=11.247
#     nt_frac=0.50 (n= 6124) | CLF-LR: cov=0.901, size=12.930 | CLF-MLP: cov=0.903, size=12.063 | AdjF: cov=0.895, size=11.412
#     nt_frac=0.60 (n= 7349) | CLF-LR: cov=0.906, size=12.764 | CLF-MLP: cov=0.906, size=12.385 | AdjF: cov=0.891, size=10.980
#     nt_frac=0.70 (n= 8574) | CLF-LR: cov=0.906, size=12.462 | CLF-MLP: cov=0.902, size=12.057 | AdjF: cov=0.892, size=11.189
#     nt_frac=0.80 (n= 9799) | CLF-LR: cov=0.904, size=12.171 | CLF-MLP: cov=0.906, size=12.016 | AdjF: cov=0.892, size=11.209
#     nt_frac=0.90 (n=11024) | CLF-LR: cov=0.907, size=12.147 | CLF-MLP: cov=0.906, size=12.174 | AdjF: cov=0.892, size=11.134
#     nt_frac=1.00 (n=12249) | CLF-LR: cov=0.910, size=12.194 | CLF-MLP: cov=0.904, size=11.593 | AdjF: cov=0.892, size=11.128
#
# Saved raw results to: cifar100_ablation_outputs/cifar100_ablation_ntfrac_results.csv
# Saved aggregated table to: cifar100_ablation_outputs/cifar100_ablation_ntfrac_agg_K4.csv
# Saved figure to:
#   cifar100_ablation_outputs/cifar100_ablation_ntfrac_cifar100_K4.pdf
#   cifar100_ablation_outputs/cifar100_ablation_ntfrac_cifar100_K4.png
